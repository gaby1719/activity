# %% [markdown]
# <a href="https://colab.research.google.com/github/gaby1719/activity/blob/main/Correlacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/gaby1719/activity/refs/heads/main/archivos/clave_D_correlacion.csv"
df = pd.read_csv(url)
df.head()
# Out:
#   cliente_id  edad  ingresos_mensuales  frecuencia_compra  ticket_promedio  \
# 0    D-C0001    28                1019                  8            62.42
# 1    D-C0002    45                1129                  6            66.92
# 2    D-C0003    44                1085                  8            68.72
# 3    D-C0004    35                1583                  9           101.45
# 4    D-C0005    38                 876                 10            79.69
#
#    satisfaccion  reclamos  uso_app  tiempo_respuesta  consumo_total
# 0          7.26         1        5             15.34         504.69
# 1          6.71         2        3             33.45         426.35
# 2          8.38         1        5             20.62         520.35
# 3          6.92         1        6             16.99         834.77
# 4          6.97         3        8             29.21         745.63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cliente_id          236 non-null    object
#  1   edad                236 non-null    int64
#  2   ingresos_mensuales  236 non-null    int64
#  3   frecuencia_compra   236 non-null    int64
#  4   ticket_promedio     235 non-null    float64
#  5   satisfaccion        235 non-null    float64
#  6   reclamos            236 non-null    int64
#  7   uso_app             236 non-null    int64
#  8   tiempo_respuesta    235 non-null    float64
#  9   consumo_total       236 non-null    float64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 18.6+ KB

# %%
df.describe()
# Out:
#              edad  ingresos_mensuales  frecuencia_compra  ticket_promedio  \
# count  236.000000          236.000000         236.000000       235.000000
# mean    37.661017         1008.542373           7.872881        62.766340
# std      9.084212          255.764275           3.246069        15.550721
# min     18.000000          381.000000           1.000000        16.080000
# 25%     32.000000          847.750000           6.000000        50.320000
# 50%     37.500000         1018.000000           8.000000        62.760000
# 75%     45.000000         1178.250000           9.000000        74.035000
# max     58.000000         1583.000000          30.000000       101.450000
#
#        satisfaccion    reclamos     uso_app  tiempo_respuesta  consumo_total
# count    235.000000  236.000000  236.000000        235.000000     236.000000
# mean       7.622043    1.500000    5.754237         20.952255     499.803686
# ...

# %%
df.isnull().sum()
# Out:
# cliente_id            0
# edad                  0
# ingresos_mensuales    0
# frecuencia_compra     0
# ticket_promedio       1
# satisfaccion          1
# reclamos              0
# uso_app               0
# tiempo_respuesta      1
# consumo_total         0
# dtype: int64

# %%
df_numeric = df.select_dtypes(include=['number'])

# %%
matriz = df_numeric.corr()
matriz
# Out:
#                         edad  ingresos_mensuales  frecuencia_compra  \
# edad                1.000000           -0.021763          -0.034514
# ingresos_mensuales -0.021763            1.000000           0.057653
# frecuencia_compra  -0.034514            0.057653           1.000000
# ticket_promedio     0.086738            0.575299          -0.029179
# satisfaccion       -0.086759            0.057425           0.213286
# reclamos            0.104874           -0.023183          -0.129755
# uso_app             0.115280            0.100913           0.355883
# tiempo_respuesta    0.073082           -0.020929          -0.221785
# consumo_total       0.026429            0.395898           0.764457
#
#                     ticket_promedio  satisfaccion  reclamos   uso_app  \
# edad                       0.086738     -0.086759  0.104874  0.115280
# ingresos_mensuales         0.575299      0.057425 -0.023183  0.100913
# frecuencia_compra         -0.029179      0.213286 -0.129755  0.355883
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(matriz, annot=True, cmap="coolwarm")
plt.title("Matriz de correlación")
plt.show()
